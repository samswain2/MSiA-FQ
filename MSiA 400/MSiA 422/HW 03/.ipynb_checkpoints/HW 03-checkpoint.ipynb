# %%
# from wwo_hist import retrieve_hist_data

import os
os.chdir(r"C:\Users\Sam\Desktop\NW Work\MSiA 422\HW 03\wd")

# frequency = 1
# start_date = '01-SEP-2022'
# end_date = '01-OCT-2022'
# api_key = '20d8713bb9ec4d0280b42849220810'

# hist_weather_data = retrieve_hist_data(api_key,
#                                 location_list,
#                                 start_date,
#                                 end_date,
#                                 frequency,
#                                 location_label = False,
#                                 export_csv = True)

# %%
location_list = ["Alabama", "Alaska", "Arkansas", "Arizona", "California",
                 "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", 
                 "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", 
                 "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", 
                 "Minnesota", "Missouri", "Mississippi", "Montana", 
                 "North_Carolina", "North_Dakota", "Nebraska", "New_Hampshire", 
                 "New_Jersey", "New_Mexico", "Nevada", "New_York", "Ohio", 
                 "Oklahoma", "Oregon", "Pennsylvania", "Rhode_Island", 
                 "South_Carolina", "South_Dakota", "Tennessee", "Texas", 
                 "Utah", "Virginia", "Vermont", "Washington", 
                 "Wisconsin", "West_Virginia", "Wyoming"]

# %%
import pandas as pd

df = pd.DataFrame()

for state in location_list:
    df_temp = pd.read_csv(r"wd/" + state + ".csv")
    df = pd.concat([df, df_temp])

# %%
df.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2022-09-01 00:00:00        24        11           0.0     11.6        4
# 1  2022-09-01 01:00:00        24        11           0.0     11.6        4
# 2  2022-09-01 02:00:00        24        11           0.0     11.6        4
# 3  2022-09-01 03:00:00        24        11           0.0     11.6        4
# 4  2022-09-01 04:00:00        24        11           0.0     11.6        4
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 35  12:11 PM  10:22 PM  06:37 AM  ...           33
# 1                 35  12:11 PM  10:22 PM  06:37 AM  ...           31
# 2                 35  12:11 PM  10:22 PM  06:37 AM  ...           29
# 3                 35  12:11 PM  10:22 PM  06:37 AM  ...           27
# 4                 35  12:11 PM  10:22 PM  06:37 AM  ...           27
#
#    cloudcover  humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# 0          87        72       0.1      1011     16          10            297
# 1          58        72       0.0      1012     15          10            287
# 2          29        73       0.0      1012     13          10            277
# 3           0        73       0.0      1013     12          10            267
# 4          23        77       0.0      1014     12          10            266
#
#    windspeedKmph  location
# 0             17   Alabama
# 1             16   Alabama
# 2             15   Alabama
# 3             13   Alabama
# 4             14   Alabama
#
# [5 rows x 25 columns]

# %%
df_grouped_stats = df.groupby(['location']).agg({'mintempC':'min','maxtempC':'max', 'tempC': 'mean'}).reset_index()
df_grouped_stats
# Out:
#           location  mintempC  maxtempC      tempC
# 0          Alabama         4        31  16.577957
# 1           Alaska        18        31  23.740591
# 2          Arizona        22        35  26.034946
# 3         Arkansas        12        41  26.760753
# 4       California        15        43  27.392473
# 5         Colorado         5        33  17.323925
# 6      Connecticut         9        33  19.865591
# 7         Delaware         3        32  18.228495
# 8          Florida         9        27  16.181452
# 9          Georgia        11        42  21.947581
# 10          Hawaii        20        38  25.961022
# 11           Idaho         1        41  18.381720
# 12        Illinois         3        39  20.369624
# 13         Indiana         8        35  20.678763
# 14            Iowa         3        41  20.677419
# 15          Kansas         7        44  24.333333
# 16        Kentucky         4        35  18.556452
# 17       Louisiana         6        41  21.700269
# 18           Maine        22        39  29.672043
# 19        Maryland         9        41  23.227151
# 20   Massachusetts         6        31  16.590054
# 21        Michigan         8        31  19.387097
# 22       Minnesota        -2        34  16.856183
# 23     Mississippi        10        40  24.336022
# 24        Missouri        17        39  27.065860
# 25         Montana         7        36  18.633065
# 26        Nebraska         7        42  23.365591
# 27          Nevada         4        39  20.400538
# 28   New_Hampshire         3        31  17.974462
# 29      New_Jersey        11        33  21.221774
# 30      New_Mexico         4        23  12.107527
# 31        New_York        11        33  21.299731
# 32  North_Carolina         9        36  22.057796
# 33    North_Dakota        -1        34  17.061828
# 34            Ohio         2        36  19.166667
# 35        Oklahoma        15        40  27.329301
# 36          Oregon        10        40  19.564516
# 37    Pennsylvania         2        31  16.228495
# 38    Rhode_Island         8        30  18.401882
# 39  South_Carolina         7        32  20.008065
# 40    South_Dakota         4        43  20.401882
# 41       Tennessee         5        40  21.158602
# 42           Texas        19        33  27.264785
# 43            Utah         3        24  13.301075
# 44         Vermont         5        41  21.346774
# 45        Virginia        15        32  23.508065
# 46      Washington         9        35  21.150538
# 47   West_Virginia         1        34  16.334677
# 48       Wisconsin         0        33  16.779570
# 49         Wyoming         3        34  18.083333

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# plt(figsize=(8, 6), dpi=80)

plt.figure(figsize=(20, 10))
plt.bar(x = df_grouped_stats["location"], height = df_grouped_stats["tempC"])
plt.xticks(rotation=75)

plt.show()

# %%
df1[df1['location'] == "Alaska"]['mean']
