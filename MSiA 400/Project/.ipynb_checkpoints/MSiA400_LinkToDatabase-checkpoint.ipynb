# %%
import psycopg2
import pandas as pd
from getpass import getpass

# %%
password = getpass("Password for MSiA: ")
conn = psycopg2.connect(
    host="pg.analytics.northwestern.edu",
    database="2022-everything-team09",
    user="sms5736", #change here
    password=password)

print("Connected.")
cur = conn.cursor()
# Out:
# Password for MSiA: ········
# Connected.

# %%
import pandas.io.sql as psql

# %%
df = psql.read_sql('SELECT * FROM public.\"skuinfo\";', conn)
# Out:
# C:\Users\nuke2\miniconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df.head(20)
# Out:
#     sku  dept                                            classid  \
# 0     0     1  2                                             ...
# 1     3  6505  113                                           ...
# 2     4  8101  002                                           ...
# 3     5  7307  003                                           ...
# 4     8  3404  00B                                           ...
# 5    15  2301  004                                           ...
# 6    20  6006  711                                           ...
# 7    23  7101  002                                           ...
# 8    24  3404  00B                                           ...
# 9    39  5301  006                                           ...
# 10   45  7101  005                                           ...
# 11   47  3404  001                                           ...
# 12   49  7106  312                                           ...
# 13   50  5404  00B                                           ...
# 14   54  8101  006                                           ...
# 15   55  7106  505                                           ...
# 16   58  7106  518                                           ...
# 17   65  5404  005                                           ...
# 18   68  7101  006                                           ...
# 19   69  7106  915                                           ...
#
#                                                   upc  \
# 0   3                                             ...
# 1   000400000003000                               ...
# 2   000400000004000                               ...
# 3   000400000005000                               ...
# 4   000400000008000                               ...
# 5   000400000015000                               ...
# 6   000400000020000                               ...
# 7   000400000023000                               ...
# 8   000400000024000                               ...
# 9   000400000039000                               ...
# 10  000400000045000                               ...
# 11  000400000047000                               ...
# 12  000400000049000                               ...
# 13  000400000050000                               ...
# 14  000400000054000                               ...
# 15  000400000055000                               ...
# 16  000400000058000                               ...
# 17  000400000065000                               ...
# 18  000400000068000                               ...
# 19  000400000069000                               ...
#
#                                                 style  \
# 0   4                                             ...
# 1   00    F55KT2                                  ...
# 2   22    615CZ4                                  ...
# 3   7LBS  245-01                                  ...
# 4   622   F05H84                                  ...
# 5   126   MDU461                                  ...
# 6   669N26                                        ...
# 7   18    TZMU01                                  ...
# 8   8A    9H8145                                  ...
# 9   56    CIMU03                                  ...
# 10  34    TZMU00                                  ...
# 11  37-30 445241                                  ...
# 12  01    KYRIE0                                  ...
# 13  BE-AARK6691-                                  ...
# 14  74    F4483H                                  ...
# 15  ATO550NWSALV                                  ...
# 16  ILY260NWRAND                                  ...
# 17  15-01 444542                                  ...
# 18  56    TZMU00                                  ...
# 19  WINDY                                         ...
#
#                                                 color  \
# 0   5                                             ...
# 1   WHISPERWHITE                                  ...
# 2   SPEARMI                                       ...
# 3   34 SILVER                                     ...
# 4   MORNING MI                                    ...
# 5   255CAMEL                                      ...
# 6   NEWPORT NA                                    ...
# 7   ICED BERRY                                    ...
# 8   428MEDIUM ST                                  ...
# 9   PRALINE                                       ...
# 10  BARK/SEASP                                    ...
# 11  GREEN                                         ...
# 12  BLACK LE                                      ...
# 13  BLACK                                         ...
# 14  HEATHER/MI                                    ...
# 15  DPUR/DPU F                                    ...
# 16  MED NATU L                                    ...
# 17  ASSORTED                                      ...
# 18  PEACOCK                                       ...
# 19  RED CALF                                      ...
#
#                                                  size  packsize  \
# 0   6                                             ...         7
# 1   P8EA                                          ...         1
# 2   S                                             ...         1
# 3   KING                                          ...         1
# 4   2T                                            ...         1
# 5   12                                            ...         1
# 6   090N                                          ...         1
# 7   S                                             ...         1
# 8   2                                             ...         1
# 9   16   ND                                       ...         1
# 10  10                                            ...         1
# 11  6X                                            ...         1
# 12  P286                                          ...         1
# 13  5                                             ...         1
# 14  SMALL                                         ...         1
# 15  090M                                          ...         1
# 16  075M                                          ...         1
# 17  5                                             ...         1
# 18  4                                             ...         1
# 19  070M                                          ...         1
#
#                                                vendor  \
# 0   8                                             ...
# 1   5119207                                       ...
# 2   3311144                                       ...
# 3   5510554                                       ...
# 4   2912827                                       ...
# 5   0023272                                       ...
# 6   0060904                                       ...
# 7   3313116                                       ...
# 8   4810170                                       ...
# 9   6515973                                       ...
# 10  3313116                                       ...
# 11  0914938                                       ...
# 12  5010255                                       ...
# 13  6713321                                       ...
# 14  0814935                                       ...
# 15  0614761                                       ...
# 16  0614761                                       ...
# 17  0934938                                       ...
# 18  3313116                                       ...
# 19  4816434                                       ...
#
#                                                 brand  unknown
# 0   9                                             ...       10
# 1   TURNBURY                                      ...        0
# 2   C A SPOR                                      ...        0
# 3   BEAU IDE                                      ...        0
# 4   HARTSTRI                                      ...        0
# 5   JONES/LA                                      ...        0
# 6   BROWN SH                                      ...        0
# 7   EMMA JAM                                      ...        0
# 8   AMERICAN                                      ...        0
# 9   SIGRID O                                      ...        0
# 10  EMMA JAM                                      ...        0
# 11  KIDS HEA                                      ...        0
# 12  ENZO ANG                                      ...        0
# 13  LOLLYTOG                                      ...        0
# 14  FU DA IN                                      ...        0
# 15  NINE WES                                      ...        0
# 16                                               None        0
# 17  KIDS HEA                                      ...        0
# 18  EMMA JAM                                      ...        0
# 19  ME TOO                                        ...        1

# %%
df = psql.read_sql("""SELECT orgprice, amt FROM public.\"trnsact\";""", conn)
# Out:
# C:\Users\nuke2\miniconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# df.mean()
df[df.amt > 0].mean()
# Out:
# amt    24.867957
# dtype: float64

# %%
# df = pd.read_csv("deptinfo.csv")
# df.to_sql("test_schema.dept_python_import", con=conn, if_exists="replace", index=False)

# %%
# # Make the changes to the database persistent
# conn.commit()
# Close communication with the database
cur.close()
conn.close()
