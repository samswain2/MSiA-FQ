# %%
df = pd.read_csv("C:/Users/Rain0/Desktop/practicum/A_DeviceMotion_data/A_DeviceMotion_data/dws_1/sub_1.csv")
df
# Out:
#       Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0              0       1.528132       -0.733896      0.696372   0.741895
# 1              1       1.527992       -0.716987      0.677762   0.753099
# 2              2       1.527765       -0.706999      0.670951   0.759611
# 3              3       1.516768       -0.704678      0.675735   0.760709
# 4              4       1.493941       -0.703918      0.672994   0.760062
# ...          ...            ...             ...           ...        ...
# 1746        1746       1.797120       -0.562324      2.445889   0.824443
# 1747        1747       1.814297       -0.569719      2.449655   0.817212
# 1748        1748       1.830821       -0.578367      2.447967   0.809207
# 1749        1749       1.849557       -0.586962      2.439458   0.800485
# 1750        1750       1.869375       -0.596783      2.433775   0.790551
#
#       gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %% [markdown]
# ## Combine datasets, add time, choose data type and activity type

# %%
import numpy as np
import pandas as pd

def get_ds_infos():
    """
    Read the file includes data subject information.
    
    Data Columns:
    0: code [1-24]
    1: weight [kg]
    2: height [cm]
    3: age [years]
    4: gender [0:Female, 1:Male]
    
    Returns:
        A pandas DataFrame that contains inforamtion about data subjects' attributes 
    """ 

    dss = pd.read_csv("C:/Users/Rain0/Desktop/practicum/data_subjects_info.csv")
    print("[INFO] -- Data subjects' information is imported.")
    
    return dss

def set_data_types(data_types=["userAcceleration"]):
    """
    Select the sensors and the mode to shape the final dataset.
    
    Args:
        data_types: A list of sensor data type from this list: [attitude, gravity, rotationRate, userAcceleration] 

    Returns:
        It returns a list of columns to use for creating time-series from files.
    """
    dt_list = []
    for t in data_types:
        if t != "attitude":
            dt_list.append([t+".x",t+".y",t+".z"])
        else:
            dt_list.append([t+".roll", t+".pitch", t+".yaw"])

    return dt_list


def creat_time_series(dt_list, act_labels, trial_codes, mode="mag", labeled=True):
    """
    Args:
        dt_list: A list of columns that shows the type of data we want.
        act_labels: list of activites
        trial_codes: list of trials
        mode: It can be "raw" which means you want raw data
        for every dimention of each data type,
        [attitude(roll, pitch, yaw); gravity(x, y, z); rotationRate(x, y, z); userAcceleration(x,y,z)].
        or it can be "mag" which means you only want the magnitude for each data type: (x^2+y^2+z^2)^(1/2)
        labeled: True, if we want a labeld dataset. False, if we only want sensor values.

    Returns:
        It returns a time-series of sensor data.
    
    """
    num_data_cols = len(dt_list) if mode == "mag" else len(dt_list*3)

    if labeled:
        dataset = np.zeros((0,num_data_cols+7)) # "7" --> [act, code, weight, height, age, gender, trial] 
    else:
        dataset = np.zeros((0,num_data_cols))
        
    ds_list = get_ds_infos()
    
    print("[INFO] -- Creating Time-Series")
    for sub_id in ds_list["code"]:
        for act_id, act in enumerate(act_labels):
            for trial in trial_codes[act_id]:
                fname = "C:/Users/Rain0/Desktop/practicum/A_DeviceMotion_data/A_DeviceMotion_data/"+act+'_'+str(trial)+'/sub_'+str(int(sub_id))+'.csv'
                raw_data = pd.read_csv(fname)
                raw_data = raw_data.drop(['Unnamed: 0'], axis=1)
                vals = np.zeros((len(raw_data), num_data_cols))
                for x_id, axes in enumerate(dt_list):
                    if mode == "mag":
                        vals[:,x_id] = (raw_data[axes]**2).sum(axis=1)**0.5        
                    else:
                        vals[:,x_id*3:(x_id+1)*3] = raw_data[axes].values
                    vals = vals[:,:num_data_cols]
                if labeled:
                    lbls = np.array([[act_id,
                            sub_id-1,
                            ds_list["weight"][sub_id-1],
                            ds_list["height"][sub_id-1],
                            ds_list["age"][sub_id-1],
                            ds_list["gender"][sub_id-1],
                            trial          
                           ]]*len(raw_data))
                    vals = np.concatenate((vals, lbls), axis=1)
                dataset = np.append(dataset,vals, axis=0)
    cols = []
    for axes in dt_list:
        if mode == "raw":
            cols += axes
        else:
            cols += [str(axes[0][:-2])]
            
    if labeled:
        cols += ["act", "id", "weight", "height", "age", "gender", "trial"]
    
    dataset = pd.DataFrame(data=dataset, columns=cols)
    return dataset
#________________________________


ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}

## Here we set parameter to build labeld time-series from dataset of "(A)DeviceMotion_data"
## attitude(roll, pitch, yaw); gravity(x, y, z); rotationRate(x, y, z); userAcceleration(x,y,z)
sdt = ["attitude", "userAcceleration"]
print("[INFO] -- Selected sensor data types: "+str(sdt))    
act_labels = ACT_LABELS [0:4]
print("[INFO] -- Selected activites: "+str(act_labels))    
trial_codes = [TRIAL_CODES[act] for act in act_labels]
dt_list = set_data_types(sdt)
dataset = creat_time_series(dt_list, act_labels, trial_codes, mode="raw", labeled=True)
print("[INFO] -- Shape of time-Series dataset:"+str(dataset.shape))    
dataset.head()
# Out:
# [INFO] -- Selected sensor data types: ['attitude', 'userAcceleration']
# [INFO] -- Selected activites: ['dws', 'ups', 'wlk', 'jog']
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series
# [INFO] -- Shape of time-Series dataset:(767660, 13)
#    attitude.roll  attitude.pitch  attitude.yaw  userAcceleration.x  \
# 0       1.528132       -0.733896      0.696372            0.294894
# 1       1.527992       -0.716987      0.677762            0.219405
# 2       1.527765       -0.706999      0.670951            0.010714
# 3       1.516768       -0.704678      0.675735           -0.008389
# 4       1.493941       -0.703918      0.672994            0.199441
#
#    userAcceleration.y  userAcceleration.z  act   id  weight  height   age  \
# 0           -0.184493            0.377542  0.0  0.0   102.0   188.0  46.0
# 1            0.035846            0.114866  0.0  0.0   102.0   188.0  46.0
# 2            0.134701           -0.167808  0.0  0.0   102.0   188.0  46.0
# ...

# %%
dataset
# Out:
#         attitude.roll  attitude.pitch  attitude.yaw  userAcceleration.x  \
# 0            1.528132       -0.733896      0.696372            0.294894
# 1            1.527992       -0.716987      0.677762            0.219405
# 2            1.527765       -0.706999      0.670951            0.010714
# 3            1.516768       -0.704678      0.675735           -0.008389
# 4            1.493941       -0.703918      0.672994            0.199441
# ...               ...             ...           ...                 ...
# 767655      -1.553643       -1.207026     -2.015848           -0.090358
# 767656      -1.533934       -1.243476     -2.010537            0.775085
# 767657      -1.301587       -1.362634     -1.783378            0.862655
# 767658      -0.524913       -1.486641     -0.952944            0.660700
# 767659       0.683482       -1.435057      0.377682            0.043053
#
#         userAcceleration.y  userAcceleration.z  act    id  weight  height  \
# ...

# %%
import os
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## check null

# %%
dataset.isnull().sum()
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# act                   0
# id                    0
# weight                0
# height                0
# age                   0
# gender                0
# trial                 0
# dtype: int64

# %% [markdown]
# ## graphs

# %% [markdown]
# ### Downstair Example

# %% [markdown]
# ### Downstair -- attitude

# %%
dt_list = set_data_types(["attitude"])
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}
#trial_codes = [TRIAL_CODES[act] for act in act_labels]
trial_codes = [[1]]
act_labels = ACT_LABELS[0:1]
df_dws_at = creat_time_series(dt_list, act_labels, trial_codes, mode="raw", labeled=True)
# Out:
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series

# %%
df_dws_at
# Out:
#        attitude.roll  attitude.pitch  attitude.yaw  act    id  weight  height  \
# 0           1.528132       -0.733896      0.696372  0.0   0.0   102.0   188.0
# 1           1.527992       -0.716987      0.677762  0.0   0.0   102.0   188.0
# 2           1.527765       -0.706999      0.670951  0.0   0.0   102.0   188.0
# 3           1.516768       -0.704678      0.675735  0.0   0.0   102.0   188.0
# 4           1.493941       -0.703918      0.672994  0.0   0.0   102.0   188.0
# ...              ...             ...           ...  ...   ...     ...     ...
# 50241       1.900272       -1.384036      1.070332  0.0  23.0    74.0   173.0
# 50242       1.996873       -1.369482      1.160633  0.0  23.0    74.0   173.0
# 50243       2.074751       -1.350028      1.228313  0.0  23.0    74.0   173.0
# 50244       2.139869       -1.337114      1.289072  0.0  23.0    74.0   173.0
# 50245       2.272042       -1.327628      1.417406  0.0  23.0    74.0   173.0
#
#         age  gender  trial
# ...

# %%
plt.figure(figsize=(16,10))
plt.ylim(-5,5)
sns.lineplot(data = df_dws_at.iloc[:,:3][(df_dws.id == 0)])
plt.show()

# %% [markdown]
# ### Downstair -- gravity

# %%
dt_list = set_data_types(["gravity"])
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}
#trial_codes = [TRIAL_CODES[act] for act in act_labels]
trial_codes = [[1]]
act_labels = ACT_LABELS[0:1]
df_dws_g = creat_time_series(dt_list, act_labels, trial_codes, mode="raw", labeled=True)
# Out:
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series

# %%
df_dws_g
# Out:
#        gravity.x  gravity.y  gravity.z  act    id  weight  height   age  \
# 0       0.741895   0.669768  -0.031672  0.0   0.0   102.0   188.0  46.0
# 1       0.753099   0.657116  -0.032255  0.0   0.0   102.0   188.0  46.0
# 2       0.759611   0.649555  -0.032707  0.0   0.0   102.0   188.0  46.0
# 3       0.760709   0.647788  -0.041140  0.0   0.0   102.0   188.0  46.0
# 4       0.760062   0.647210  -0.058530  0.0   0.0   102.0   188.0  46.0
# ...          ...        ...        ...  ...   ...     ...     ...   ...
# 50241   0.175689   0.982611   0.060075  0.0  23.0    74.0   173.0  18.0
# 50242   0.182080   0.979805   0.082643  0.0  23.0    74.0   173.0  18.0
# 50243   0.191755   0.975730   0.105743  0.0  23.0    74.0   173.0  18.0
# 50244   0.195067   0.972820   0.124777  0.0  23.0    74.0   173.0  18.0
# 50245   0.183965   0.970580   0.155344  0.0  23.0    74.0   173.0  18.0
#
#        gender  trial
# 0         1.0    1.0
# 1         1.0    1.0
# 2         1.0    1.0
# ...

# %%
plt.figure(figsize=(16,10))
plt.ylim(-3,3)
sns.lineplot(data = df_dws_g.iloc[:,:3][(df_dws_g.id == 0)])
plt.show()

# %% [markdown]
# ### Downstair -- all

# %%
dt_list = set_data_types(["attitude", "userAcceleration", "gravity", "rotationRate"])
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}
#trial_codes = [TRIAL_CODES[act] for act in act_labels]
trial_codes = [[1]]
act_labels = ACT_LABELS[0:1]
df_dws_all = creat_time_series(dt_list, act_labels, trial_codes, mode="raw", labeled=True)
# Out:
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series

# %%
df_dws_all
# Out:
#        attitude.roll  attitude.pitch  attitude.yaw  userAcceleration.x  \
# 0           1.528132       -0.733896      0.696372            0.294894
# 1           1.527992       -0.716987      0.677762            0.219405
# 2           1.527765       -0.706999      0.670951            0.010714
# 3           1.516768       -0.704678      0.675735           -0.008389
# 4           1.493941       -0.703918      0.672994            0.199441
# ...              ...             ...           ...                 ...
# 50241       1.900272       -1.384036      1.070332           -0.625930
# 50242       1.996873       -1.369482      1.160633           -1.038052
# 50243       2.074751       -1.350028      1.228313           -1.018690
# 50244       2.139869       -1.337114      1.289072           -0.710647
# 50245       2.272042       -1.327628      1.417406           -0.578099
#
#        userAcceleration.y  userAcceleration.z  gravity.x  gravity.y  \
# ...

# %%
plt.figure(figsize=(16,10))
plt.ylim(-6,6)
sns.lineplot(data = df_dws_all.iloc[:,:12][(df_dws_all.id == 0)])
plt.show()

# %% [markdown]
# ## user acceleration for sit activity

# %%
dt_list = set_data_types(["userAcceleration"])
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}
#trial_codes = [TRIAL_CODES[act] for act in act_labels]
trial_codes = [[5]]
act_labels = ACT_LABELS[5:6]
df_sit = creat_time_series(dt_list, act_labels, trial_codes, mode="mag", labeled=True)
# Out:
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series

# %%
df_sit
# Out:
#         userAcceleration  act    id  weight  height   age  gender  trial
# 0               0.006959  0.0   0.0   102.0   188.0  46.0     1.0    5.0
# 1               0.010673  0.0   0.0   102.0   188.0  46.0     1.0    5.0
# 2               0.007010  0.0   0.0   102.0   188.0  46.0     1.0    5.0
# 3               0.014892  0.0   0.0   102.0   188.0  46.0     1.0    5.0
# 4               0.013001  0.0   0.0   102.0   188.0  46.0     1.0    5.0
# ...                  ...  ...   ...     ...     ...   ...     ...    ...
# 234652          0.120682  0.0  23.0    74.0   173.0  18.0     0.0    5.0
# 234653          0.050137  0.0  23.0    74.0   173.0  18.0     0.0    5.0
# 234654          0.050704  0.0  23.0    74.0   173.0  18.0     0.0    5.0
# 234655          0.056800  0.0  23.0    74.0   173.0  18.0     0.0    5.0
# 234656          0.063745  0.0  23.0    74.0   173.0  18.0     0.0    5.0
#
# [234657 rows x 8 columns]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(16,16))
for i in range(1,9):
    ax1.plot(df_sit.userAcceleration[(df_sit.id == i)], label='subject %d' %i)
    ax1.legend(loc="upper right")
for i in range(9,17):
    ax2.plot(df_sit.userAcceleration[(df_sit.id == i)], label='subject %d' %i)
    ax2.legend(loc="upper right")
for i in range(17,25):
    ax3.plot(df_sit.userAcceleration[(df_sit.id == i)], label='subject %d' %i)
    ax3.legend(loc="upper right")

# %% [markdown]
# 18th person has weird acceleration

# %% [markdown]
# ## All activities

# %%
dt_list = set_data_types(["attitude", "userAcceleration", "gravity", "rotationRate"])
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}
trial_codes = [TRIAL_CODES[act] for act in act_labels]
#trial_codes = [[5]]
act_labels = ACT_LABELS[0:6]
df_all = creat_time_series(dt_list, act_labels, trial_codes, mode="mag", labeled=True)
# Out:
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series

# %%
df_all
# Out:
#          attitude.ro  userAcceleration  gravity  rotationRate  act    id  \
# 0           1.832682          0.513360      1.0      1.370498  0.0   0.0
# 1           1.818843          0.250235      1.0      1.141648  0.0   0.0
# 2           1.812205          0.215450      1.0      0.372530  0.0   0.0
# 3           1.803822          0.166728      1.0      1.049628  0.0   0.0
# 4           1.783334          0.408720      1.0      0.921229  0.0   0.0
# ...              ...               ...      ...           ...  ...   ...
# 1412860     2.400409          0.007405      1.0      0.011657  5.0  23.0
# 1412861     2.400876          0.000739      1.0      0.022209  5.0  23.0
# 1412862     2.401263          0.002219      1.0      0.014941  5.0  23.0
# 1412863     2.401523          0.005844      1.0      0.008240  5.0  23.0
# 1412864     2.401558          0.006285      1.0      0.016831  5.0  23.0
#
#          weight  height   age  gender  trial
# 0         102.0   188.0  46.0     1.0    1.0
# ...

# %%
fig, ax = plt.subplots(figsize=(15,8))

plt.title('Mean acceleration for all activities:')
ax = sns.barplot(x=df_all.act, y=df_all.userAcceleration, ci='sd')
ax.set_xticks(range(6)) # <--- set the ticks first
ax.set_xticklabels(["dws","ups", "wlk", "jog", "std", "sit"])
#ax.show()
# Out:
# [Text(0, 0, 'dws'),
#  Text(1, 0, 'ups'),
#  Text(2, 0, 'wlk'),
#  Text(3, 0, 'jog'),
#  Text(4, 0, 'std'),
#  Text(5, 0, 'sit')]

# %%
fig, ax = plt.subplots(figsize=(15,8))

plt.title('Mean gravity for all activities:')
ax = sns.barplot(x=df_all.act, y=df_all.gravity, ci='sd')
ax.set_xticks(range(6)) # <--- set the ticks first
ax.set_xticklabels(["dws","ups", "wlk", "jog", "std", "sit"])
# Out:
# [Text(0, 0, 'dws'),
#  Text(1, 0, 'ups'),
#  Text(2, 0, 'wlk'),
#  Text(3, 0, 'jog'),
#  Text(4, 0, 'std'),
#  Text(5, 0, 'sit')]

# %%
fig, ax = plt.subplots(figsize=(15,8))

plt.title('Mean rotationRate for all activities:')
ax = sns.barplot(x=df_all.act, y=df_all.rotationRate, ci='sd')
ax.set_xticks(range(6)) # <--- set the ticks first
ax.set_xticklabels(["dws","ups", "wlk", "jog", "std", "sit"])
# Out:
# [Text(0, 0, 'dws'),
#  Text(1, 0, 'ups'),
#  Text(2, 0, 'wlk'),
#  Text(3, 0, 'jog'),
#  Text(4, 0, 'std'),
#  Text(5, 0, 'sit')]

# %%
fig, ax = plt.subplots(figsize=(15,8))

plt.title('Mean rotationRate for all activities:')
ax = sns.barplot(x=df_all.act, y=df_all["attitude.ro"], ci='sd')
ax.set_xticks(range(6)) # <--- set the ticks first
ax.set_xticklabels(["dws","ups", "wlk", "jog", "std", "sit"])
# Out:
# [Text(0, 0, 'dws'),
#  Text(1, 0, 'ups'),
#  Text(2, 0, 'wlk'),
#  Text(3, 0, 'jog'),
#  Text(4, 0, 'std'),
#  Text(5, 0, 'sit')]
