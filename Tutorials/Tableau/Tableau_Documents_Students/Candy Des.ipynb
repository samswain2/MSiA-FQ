# %%
import pandas as pd

# %%
df =  pd.read_csv(r"candy_data.csv", index_col = 0)

# %%
df.sort_values(by=['winpercent', 'sugarpercent'], ascending = False).head(10)
# Out:
#                   competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 52    ReeseÕs Peanut Butter cup          1       0        0               1
# 51           ReeseÕs Miniatures          1       0        0               1
# 79                          Twix          1       0        1               0
# 28                       Kit Kat          1       0        0               0
# 64                      Snickers          1       0        1               1
# 53               ReeseÕs pieces          1       0        0               1
# 36                     Milky Way          1       0        1               0
# 54  ReeseÕs stuffed with pieces          1       0        0               1
# 32          Peanut butter M&MÕs          1       0        0               1
# 42           Nestle Butterfinger          1       0        0               1
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 52       0                 0     0    0         0         0.720         0.651
# 51       0                 0     0    0         0         0.034         0.279
# 79       0                 1     0    1         0         0.546         0.906
# 28       0                 1     0    1         0         0.313         0.511
# 64       1                 0     0    1         0         0.546         0.651
# 53       0                 0     0    0         1         0.406         0.651
# 36       1                 0     0    1         0         0.604         0.651
# 54       0                 0     0    0         0         0.988         0.651
# 32       0                 0     0    0         1         0.825         0.651
# 42       0                 0     0    1         0         0.604         0.767
#
#     winpercent       pc1       pc2
# 52   84.180290  0.974319  0.341707
# 51   81.866257  0.686277  0.175222
# 79   81.642914  1.223406 -0.265272
# 28   76.768600  0.872880 -0.177105
# 64   76.673782  1.352883 -0.191581
# 53   73.434990  0.206463  1.031160
# 36   73.099556  1.272955 -0.398975
# 54   72.887901  0.764726  0.204357
# 32   71.465050  0.532143  0.936357
# 42   70.735641  1.033092 -0.150080
